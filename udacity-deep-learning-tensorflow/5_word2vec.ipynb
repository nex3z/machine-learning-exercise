# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.125834
# Nearest to with: trophy, drugged, catholics, rap, oc, cristo, cod, aztlan,
# Nearest to he: airs, showgirl, uk, royston, apologists, pound, carotene, upgraded,
# Nearest to by: ranches, ergo, tainted, taboo, busby, nutrition, honor, seated,
# Nearest to two: kalmar, reckoning, oc, unfinished, hcl, oscillator, terra, unbelief,
# Nearest to most: piast, infinitives, galba, festival, artefacts, dysfunctional, mothers, gernika,
# Nearest to while: liliales, indicted, delicately, jockeys, subscriptions, accessories, conformist, show,
# Nearest to at: cluster, abolish, strands, apparition, meltwater, abused, congregations, diurnal,
# Nearest to to: drifting, sitter, milo, cobain, shimazu, edifices, ie, cracking,
# Nearest to these: conti, serials, escherichia, criticises, geocentric, auteur, kitchen, strictness,
# Nearest to over: obscured, parables, jettisoned, facilities, interpreter, interment, psalms, devolved,
# Nearest to so: magna, aloha, reptiles, alma, mileva, istat, burglar, prose,
# Nearest to first: driver, actress, ear, prelude, autobahn, geologist, bystander, rims,
# Nearest to years: arctan, animaniacs, hearsay, freeh, sheen, maintaining, famicom, arrian,
# Nearest to between: fight, paddy, rugged, outset, underlined, benzyl, hun, capac,
# Nearest to zero: downplayed, mems, cfm, depress, successively, commercialized, pantheon, hobbies,
# Nearest to other: racine, monotonicity, gon, vat, mie, containing, comit, toothpaste,
# Average loss at step 2000: 4.371615
# Average loss at step 4000: 3.864931
# Average loss at step 6000: 3.792986
# Average loss at step 8000: 3.691554
# Average loss at step 10000: 3.612933
# Nearest to with: qarase, in, into, within, trophy, by, yamaguchi, lair,
# Nearest to he: it, they, she, who, shah, ethiopic, defamation, also,
# Nearest to by: cornish, been, as, das, was, with, wears, carradine,
# Nearest to two: three, four, five, six, seven, eight, nine, one,
# Nearest to most: piast, hc, mothers, thermonuclear, dysfunctional, suharto, conclave, jens,
# Nearest to while: xvii, delicately, sweyn, were, and, show, comparative, throttled,
# Nearest to at: in, on, apparition, congregations, spell, of, from, cluster,
# Nearest to to: merges, wavering, consultative, not, training, pissarro, edifices, deteriorating,
# Nearest to these: many, criticises, bisexuals, escherichia, platelets, unger, some, seater,
# Nearest to over: inclinations, patricio, jettisoned, sundance, interpreter, facilities, detecting, campion,
# Nearest to so: reptiles, aloha, magna, renamed, it, resulted, beltane, radiology,
# Nearest to first: geologist, evident, devon, at, rail, prelude, driver, adjectives,
# Nearest to years: arctan, hearsay, abc, lupus, animaniacs, variably, statehood, phobia,
# Nearest to between: rugged, paddy, robeson, sight, isp, sandwiches, detonating, reduplication,
# Nearest to zero: eight, six, nine, seven, three, five, four, two,
# Nearest to other: racine, sukkot, stable, aquifer, submersible, chau, engineers, physically,
# Average loss at step 12000: 3.607117
# Average loss at step 14000: 3.577036
# Average loss at step 16000: 3.408763
# Average loss at step 18000: 3.453987
# Average loss at step 20000: 3.539756
# Nearest to with: in, trophy, by, qarase, into, within, from, between,
# Nearest to he: it, she, they, who, there, never, gale, tsiolkovsky,
# Nearest to by: with, through, were, into, in, for, uh, from,
# Nearest to two: five, three, four, six, one, eight, seven, zero,
# Nearest to most: hc, more, mothers, piast, all, some, suharto, many,
# Nearest to while: were, although, comparative, industrial, zarathustra, noradrenaline, when, where,
# Nearest to at: in, on, from, committed, for, apparition, during, across,
# Nearest to to: not, merges, would, will, may, wavering, must, can,
# Nearest to these: many, some, other, dystrophy, kissed, all, milah, durand,
# Nearest to over: patricio, wendish, inclinations, pompeii, hydrosphere, obscured, refuge, between,
# Nearest to so: resulted, flex, magna, reptiles, renamed, larger, gpl, mileva,
# Nearest to first: geologist, legate, devon, second, rail, same, evident, epstein,
# Nearest to years: arctan, abc, phobia, hearsay, lupus, times, variably, days,
# Nearest to between: from, robeson, in, rugged, and, against, with, among,
# Nearest to zero: five, six, seven, eight, four, three, nine, two,
# Nearest to other: many, these, various, sukkot, containing, some, those, different,
# Average loss at step 22000: 3.502761
# Average loss at step 24000: 3.491794
# Average loss at step 26000: 3.482757
# Average loss at step 28000: 3.477751
# Average loss at step 30000: 3.501829
# Nearest to with: between, by, in, trophy, among, whereas, when, qarase,
# Nearest to he: it, she, they, who, there, never, but, this,
# Nearest to by: under, in, with, from, was, were, as, superposition,
# Nearest to two: three, one, four, six, five, eight, seven, nine,
# Nearest to most: more, hc, piast, suharto, many, some, lejeune, disgraced,
# Nearest to while: although, but, when, industrial, were, where, noradrenaline, are,
# Nearest to at: in, on, during, glare, congregations, lian, digs, committed,
# Nearest to to: would, will, merges, can, pissarro, could, for, shimazu,
# Nearest to these: some, many, various, other, their, they, dystrophy, all,
# Nearest to over: patricio, wendish, through, inclinations, pompeii, hydrosphere, about, refuge,
# Nearest to so: less, flex, agencies, bear, if, gpl, resulted, reptiles,
# Nearest to first: second, same, last, rail, crew, devon, monks, philby,
# Nearest to years: days, times, months, frodo, arctan, year, hearsay, phobia,
# Nearest to between: with, from, robeson, in, against, among, till, rugged,
# Nearest to zero: five, eight, seven, six, four, three, nine, two,
# Nearest to other: these, various, many, different, worm, some, such, engineers,
# Average loss at step 32000: 3.504911
# Average loss at step 34000: 3.492156
# Average loss at step 36000: 3.456419
# Average loss at step 38000: 3.301814
# Average loss at step 40000: 3.426590
# Nearest to with: between, trophy, by, classic, against, implementing, rap, byrnes,
# Nearest to he: she, it, they, who, there, never, i, finally,
# Nearest to by: with, for, be, was, uh, abiotic, as, lj,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to most: more, many, hc, some, suharto, disgraced, randle, front,
# Nearest to while: although, when, but, are, were, before, and, zarathustra,
# Nearest to at: in, on, congregations, landlords, during, for, glare, classicism,
# Nearest to to: must, will, could, can, would, merges, may, should,
# Nearest to these: many, some, both, such, their, various, those, dystrophy,
# Nearest to over: about, through, between, wendish, patricio, murnau, into, airman,
# Nearest to so: agencies, flex, less, gpl, bear, minarchists, if, pornography,
# Nearest to first: second, last, next, same, fourth, philby, legate, rail,
# Nearest to years: days, months, times, year, centuries, frodo, arctan, time,
# Nearest to between: from, with, robeson, over, against, dust, among, fda,
# Nearest to zero: five, seven, eight, nine, six, four, three, two,
# Nearest to other: various, bastien, different, these, many, containing, engineers, autos,
# Average loss at step 42000: 3.434767
# Average loss at step 44000: 3.454170
# Average loss at step 46000: 3.450669
# Average loss at step 48000: 3.356771
# Average loss at step 50000: 3.385746
# Nearest to with: between, qarase, by, irate, trophy, rubric, yerushalmi, appropriated,
# Nearest to he: she, it, they, who, there, finally, never, actually,
# Nearest to by: through, with, bookshop, was, sinn, in, ld, as,
# Nearest to two: three, four, six, one, five, eight, seven, zero,
# Nearest to most: more, some, hc, many, less, suharto, expansions, illusions,
# Nearest to while: although, when, however, but, where, after, and, including,
# Nearest to at: during, on, girth, in, congregations, digs, after, commoners,
# Nearest to to: would, pissarro, merges, rwandan, wavering, could, may, against,
# Nearest to these: some, many, both, such, several, various, dystrophy, those,
# Nearest to over: through, about, wendish, patricio, on, inclinations, obscured, facilities,
# Nearest to so: if, then, agencies, flex, minarchists, gpl, waugh, tib,
# Nearest to first: second, last, next, same, third, final, fourth, entire,
# Nearest to years: days, months, times, year, centuries, frodo, arctan, abc,
# Nearest to between: with, robeson, from, against, in, through, among, within,
# Nearest to zero: five, six, eight, seven, four, nine, three, two,
# Nearest to other: various, different, many, some, engineers, these, suppression, worm,
# Average loss at step 52000: 3.437837
# Average loss at step 54000: 3.428074
# Average loss at step 56000: 3.433572
# Average loss at step 58000: 3.397019
# Average loss at step 60000: 3.395396
# Nearest to with: between, qarase, into, by, foodcrops, in, classic, through,
# Nearest to he: she, it, they, there, who, gale, never, later,
# Nearest to by: through, superposition, with, odorless, under, without, was, sinn,
# Nearest to two: three, four, one, six, five, eight, seven, zero,
# Nearest to most: more, many, some, hc, use, suharto, illusions, expansions,
# Nearest to while: although, when, after, including, however, were, and, eavesdropping,
# Nearest to at: in, after, during, congregations, before, girth, armin, waring,
# Nearest to to: would, may, will, rwandan, wavering, merges, must, apostolic,
# Nearest to these: many, some, those, both, such, dystrophy, several, different,
# Nearest to over: through, about, wendish, into, between, patricio, inclinations, around,
# Nearest to so: if, minarchists, agencies, sometimes, less, gpl, fact, euro,
# Nearest to first: last, second, next, same, third, fourth, final, earliest,
# Nearest to years: days, months, times, centuries, year, decades, weeks, frodo,
# Nearest to between: with, robeson, among, against, within, through, over, till,
# Nearest to zero: five, four, eight, seven, six, three, two, nine,
# Nearest to other: various, different, many, including, several, suppression, engineers, astrological,
# Average loss at step 62000: 3.242520
# Average loss at step 64000: 3.256108
# Average loss at step 66000: 3.403866
# Average loss at step 68000: 3.399625
# Average loss at step 70000: 3.359873
# Nearest to with: between, without, among, within, plus, byrnes, irate, qarase,
# Nearest to he: she, it, they, there, who, we, never, later,
# Nearest to by: through, using, superposition, sondheim, cornish, in, uh, without,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to most: more, many, less, some, use, suharto, hc, invertible,
# Nearest to while: although, including, however, when, though, before, after, and,
# Nearest to at: on, during, in, girth, after, lehman, sgi, hogan,
# Nearest to to: rwandan, wavering, will, should, must, would, can, merges,
# Nearest to these: some, such, many, dystrophy, several, the, are, those,
# Nearest to over: about, through, inclinations, wendish, around, cuckoo, off, shyness,
# Nearest to so: if, sometimes, minarchists, nour, agencies, thus, jams, durango,
# Nearest to first: second, last, next, earliest, third, same, fourth, cpr,
# Nearest to years: days, months, centuries, times, decades, year, frodo, weeks,
# Nearest to between: with, within, among, dust, robeson, from, against, through,
# Nearest to zero: five, six, eight, four, seven, nine, two, three,
# Nearest to other: various, different, including, many, like, some, others, exempted,
# Average loss at step 72000: 3.369786
# Average loss at step 74000: 3.347946
# Average loss at step 76000: 3.314606
# Average loss at step 78000: 3.353036
# Average loss at step 80000: 3.384529
# Nearest to with: between, byrnes, among, into, rap, trophy, in, qarase,
# Nearest to he: she, it, they, there, who, we, never, but,
# Nearest to by: through, mutualism, uncontroversial, sinn, be, with, evoking, sleeve,
# Nearest to two: three, six, four, five, one, seven, eight, zero,
# Nearest to most: more, some, many, less, hc, among, suharto, olde,
# Nearest to while: although, however, after, when, but, though, before, and,
# Nearest to at: girth, in, after, glare, on, during, cos, comstock,
# Nearest to to: rwandan, wavering, lothar, can, would, will, should, pissarro,
# Nearest to these: several, many, those, both, some, various, such, dystrophy,
# Nearest to over: about, through, between, within, inclinations, off, around, wendish,
# Nearest to so: if, before, minarchists, sometimes, undergrowth, flocked, durango, nicomedia,
# Nearest to first: second, last, next, third, same, earliest, fourth, nafs,
# Nearest to years: days, months, centuries, decades, times, year, weeks, frodo,
# Nearest to between: within, with, among, over, through, against, dust, in,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to other: various, others, including, older, many, different, sukkot, especially,
# Average loss at step 82000: 3.409325
# Average loss at step 84000: 3.411976
# Average loss at step 86000: 3.392703
# Average loss at step 88000: 3.350420
# Average loss at step 90000: 3.367317
# Nearest to with: between, without, in, byrnes, as, irate, trophy, when,
# Nearest to he: she, it, they, there, who, but, later, we,
# Nearest to by: through, while, without, bookshop, under, during, with, superposition,
# Nearest to two: three, five, four, six, seven, eight, one, zero,
# Nearest to most: many, some, more, less, suharto, among, use, several,
# Nearest to while: although, when, after, before, though, but, and, were,
# Nearest to at: on, during, under, girth, near, after, before, congregations,
# Nearest to to: rwandan, lothar, merges, wavering, would, towards, shimazu, must,
# Nearest to these: some, several, many, various, those, are, both, such,
# Nearest to over: about, between, through, within, off, around, inclinations, wendish,
# Nearest to so: if, thus, before, jams, minarchists, flocked, yousef, nour,
# Nearest to first: last, second, next, third, same, earliest, fourth, final,
# Nearest to years: days, months, decades, centuries, year, times, weeks, bc,
# Nearest to between: with, within, among, through, over, against, from, in,
# Nearest to zero: five, seven, eight, four, six, three, nine, two,
# Nearest to other: various, individual, different, older, others, olmec, including, spying,
# Average loss at step 92000: 3.398659
# Average loss at step 94000: 3.250056
# Average loss at step 96000: 3.360245
# Average loss at step 98000: 3.247770
# Average loss at step 100000: 3.357144
# Nearest to with: between, qarase, including, designator, byrnes, among, into, brotherhood,
# Nearest to he: she, it, they, who, there, we, never, eventually,
# Nearest to by: through, superposition, forearms, suprema, medell, using, marguerite, from,
# Nearest to two: four, five, three, six, seven, eight, one, zero,
# Nearest to most: more, less, some, many, especially, use, several, interchangeably,
# Nearest to while: although, when, though, but, before, where, however, after,
# Nearest to at: on, in, during, after, near, lehman, velvet, pett,
# Nearest to to: will, would, could, must, should, can, rwandan, might,
# Nearest to these: several, some, many, those, various, such, dystrophy, different,
# Nearest to over: about, between, within, through, around, airman, wendish, nearly,
# Nearest to so: thus, if, when, consenting, then, minarchists, sometimes, less,
# Nearest to first: last, second, next, third, fourth, final, accession, earliest,
# Nearest to years: days, months, decades, centuries, year, times, weeks, frodo,
# Nearest to between: among, with, within, through, over, against, from, robeson,
# Nearest to zero: five, four, seven, six, eight, three, two, nine,
# Nearest to other: various, older, others, including, different, suppression, individual, hasmonaean,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def extract(buffer, target):
  tmp = list(buffer)
  return tmp.pop(target), tmp

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    labels[i, 0], batch[i] = extract(buffer, bag_window)
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=8, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))
  print('    batch:', [[reverse_dictionary[wi] for wi in bi] for bi in batch])
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.632323
# Nearest to been: inoculation, tallis, secrete, lamm, cautioned, trump, dyson, piped,
# Nearest to also: misquoted, screwed, ammonius, dominic, sudetenland, antonin, littoral, shifts,
# Nearest to they: expressiveness, ffts, phase, arecibo, jinn, frameworks, daoud, acidic,
# Nearest to known: continuously, abc, sorry, baudot, republican, todd, giraffes, shifted,
# Nearest to was: revere, chewing, dwan, looksmart, warbird, regulator, stunted, obrzeg,
# Nearest to five: his, quarterly, faults, invades, stags, viridis, proofs, remarkably,
# Nearest to over: projectiles, iwo, runge, mater, wyche, uranus, bactria, depicts,
# Nearest to no: tori, mosiah, contour, gianfranco, holger, judicial, boitano, felsic,
# Nearest to called: yacc, aan, echelon, baldr, port, hopeful, kimmel, crazed,
# Nearest to UNK: dynamical, celebrates, report, entomology, dance, kurz, nonce, applauded,
# Nearest to during: disputed, thinner, scala, adf, ferroelectric, purporting, maxims, groups,
# Nearest to it: ccds, akademia, ballpoint, pillaged, hoax, niki, loon, rebecca,
# Nearest to of: leverage, blended, breast, hmg, playoff, devonian, surname, raptor,
# Nearest to these: wrongdoing, interpolations, explode, nazism, oren, tudor, busan, deborah,
# Nearest to not: amides, projective, some, persistently, picirilli, station, ux, stronger,
# Nearest to history: kelley, darwinism, schizophrenia, erick, initials, flying, dendrites, mchale,
# Average loss at step 2000: 4.465525
# Average loss at step 4000: 3.869484
# Average loss at step 6000: 3.774851
# Average loss at step 8000: 3.608576
# Average loss at step 10000: 3.554225
# Nearest to been: become, runequest, han, reductase, zones, secrete, laterals, gregorian,
# Nearest to also: often, below, spent, centralizing, that, utica, floated, shabbat,
# Nearest to they: he, there, we, these, cath, it, you, crescent,
# Nearest to known: used, such, described, well, regarded, referred, ainsworth, vav,
# Nearest to was: is, became, were, has, had, makes, airy, qatar,
# Nearest to five: four, six, seven, zero, three, eight, nine, two,
# Nearest to over: mater, discontinued, aggravated, ebne, ordain, within, multiverse, asic,
# Nearest to no: any, buenos, akiva, recognition, contour, polluted, boitano, penance,
# Nearest to called: treating, considered, residential, recovers, cannibalistic, luk, used, willfully,
# Nearest to UNK: partially, conceit, polyalphabetic, notified, reintroduction, contracts, marker, wreckage,
# Nearest to during: after, in, until, at, mater, wilde, first, last,
# Nearest to it: he, this, she, they, earnhardt, remarking, rescues, macquarie,
# Nearest to of: dolmen, in, goodfellas, for, and, leena, memorization, juris,
# Nearest to these: different, several, some, many, they, torrent, watson, various,
# Nearest to not: impeach, fungal, fascination, recognises, shinoda, serif, fallacies, shatter,
# Nearest to history: caledonia, kelley, protoscience, fad, proceeding, derivates, brazen, roadmap,
# Average loss at step 12000: 3.532790
# Average loss at step 14000: 3.517912
# Average loss at step 16000: 3.366718
# Average loss at step 18000: 3.150590
# Average loss at step 20000: 3.219227
# Nearest to been: become, come, jornal, be, alchemists, eastenders, no, diva,
# Nearest to also: still, often, below, what, where, unreachable, wastewater, mandrakesoft,
# Nearest to they: you, we, she, he, artcyclopedia, pics, there, psychotic,
# Nearest to known: described, used, referred, regarded, such, seen, well, see,
# Nearest to was: is, were, became, are, had, huldrych, has, being,
# Nearest to five: seven, eight, four, six, nine, zero, three, two,
# Nearest to over: ebne, before, mater, aggravated, campaigned, authoritarianism, northeastern, repulsion,
# Nearest to no: any, holly, nothing, deo, token, been, refreshed, eastenders,
# Nearest to called: considered, used, known, there, found, named, ieung, cronquist,
# Nearest to UNK: asymptotic, heuss, hohenstaufen, jagger, choir, dxm, hermione, impeller,
# Nearest to during: after, in, until, before, at, when, last, within,
# Nearest to it: he, she, this, usurpers, voip, there, beatmatching, what,
# Nearest to of: among, within, npd, hmg, gokturks, pohl, including, vl,
# Nearest to these: various, some, the, several, many, those, all, other,
# Nearest to not: impeach, monastic, jadwiga, never, basso, serif, arabians, aluma,
# Nearest to history: contraband, caledonia, economy, study, development, versions, mdf, aden,
# Average loss at step 22000: 3.372180
# Average loss at step 24000: 3.228103
# Average loss at step 26000: 3.250175
# Average loss at step 28000: 3.311463
# Average loss at step 30000: 3.194000
# Nearest to been: become, bind, breisgau, remained, diva, be, come, disparaged,
# Nearest to also: below, often, still, now, where, what, soo, cnn,
# Nearest to they: we, he, you, she, there, pics, artcyclopedia, it,
# Nearest to known: referred, used, described, regarded, considered, such, seen, served,
# Nearest to was: is, were, became, had, are, has, hiatus, ovarian,
# Nearest to five: four, three, six, eight, zero, seven, two, nine,
# Nearest to over: before, aggravated, ebne, during, after, when, fervor, through,
# Nearest to no: any, a, harmonising, only, achieving, hoffmann, little, contour,
# Nearest to called: considered, named, described, known, see, used, found, anabaptists,
# Nearest to UNK: dxm, gottlieb, soprano, de, ronald, incised, des, andrew,
# Nearest to during: after, before, in, until, since, at, following, through,
# Nearest to it: she, he, this, which, they, what, andhra, there,
# Nearest to of: heaps, auditors, including, woodson, arsacid, intra, during, cer,
# Nearest to these: different, various, other, those, some, certain, several, maloney,
# Nearest to not: never, still, now, also, aemilius, without, currently, freud,
# Nearest to history: development, list, life, takeovers, versions, rebuilding, because, modern,
# Average loss at step 32000: 3.179386
# Average loss at step 34000: 3.150125
# Average loss at step 36000: 3.070822
# Average loss at step 38000: 3.094523
# Average loss at step 40000: 3.103746
# Nearest to been: become, gone, appeared, begun, runequest, breisgau, diva, already,
# Nearest to also: below, still, often, never, now, usually, wonderswan, michaux,
# Nearest to they: we, you, there, he, hippolytus, throwers, she, bahr,
# Nearest to known: described, referred, used, regarded, considered, seen, available, called,
# Nearest to was: is, were, became, had, being, has, are, becomes,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to over: during, aggravated, within, across, under, premiership, ebne, sublimation,
# Nearest to no: any, nothing, only, a, deconstruction, little, galante, ende,
# Nearest to called: considered, named, known, described, see, used, created, referred,
# Nearest to UNK: wark, marie, barney, examines, de, die, controllable, corpus,
# Nearest to during: in, after, until, before, against, omits, throughout, over,
# Nearest to it: she, he, there, this, earnhardt, edlin, voip, gatherings,
# Nearest to of: including, include, arsacid, intra, gokturks, leena, through, goodfellas,
# Nearest to these: different, various, other, those, some, certain, several, many,
# Nearest to not: never, still, picket, wim, without, apparition, serif, inelastic,
# Nearest to history: development, employment, list, aleut, buddhism, tradition, disapproval, origin,
# Average loss at step 42000: 3.103389
# Average loss at step 44000: 3.139329
# Average loss at step 46000: 3.082706
# Average loss at step 48000: 2.966941
# Average loss at step 50000: 3.100251
# Nearest to been: become, come, be, runequest, already, contributed, appeared, previously,
# Nearest to also: often, below, still, now, which, usually, never, sometimes,
# Nearest to they: we, he, you, there, she, clap, hippolytus, severely,
# Nearest to known: referred, described, possible, available, used, seen, regarded, responsible,
# Nearest to was: is, became, were, remained, are, makes, becomes, had,
# Nearest to five: six, three, zero, four, seven, eight, two, nine,
# Nearest to over: across, within, during, under, through, selkirk, premiership, involving,
# Nearest to no: any, nothing, a, little, still, another, escaped, circumcision,
# Nearest to called: considered, named, known, used, released, described, created, introduced,
# Nearest to UNK: wuthering, facto, goto, stirrups, legalization, eng, conceptions, captain,
# Nearest to during: in, throughout, after, through, before, since, until, valdemar,
# Nearest to it: he, she, this, phospholipid, earnhardt, there, sufficient, voip,
# Nearest to of: gokturks, heaps, ccf, during, bihari, remotely, since, in,
# Nearest to these: various, certain, several, numerous, many, different, those, dicaprio,
# Nearest to not: never, still, now, middens, without, usually, ocogs, currently,
# Nearest to history: list, disapproval, suffixed, journal, lorica, development, blockaded, employment,
# Average loss at step 52000: 3.072870
# Average loss at step 54000: 3.065658
# Average loss at step 56000: 3.086666
# Average loss at step 58000: 3.004720
# Average loss at step 60000: 2.835477
# Nearest to been: become, come, gone, grown, occurred, appeared, be, breisgau,
# Nearest to also: now, often, below, still, sometimes, generally, what, which,
# Nearest to they: we, you, he, there, she, pics, clap, throwers,
# Nearest to known: referred, described, regarded, seen, defined, such, used, follows,
# Nearest to was: is, were, became, becomes, are, hiatus, remains, remained,
# Nearest to five: four, eight, six, three, zero, seven, nine, two,
# Nearest to over: through, across, around, medicare, vocally, about, krzysztof, cetacea,
# Nearest to no: little, any, nothing, still, nye, shutter, beecher, collectible,
# Nearest to called: considered, used, named, known, added, see, introduced, created,
# Nearest to UNK: de, et, p, carradine, endymion, prism, mda, meaning,
# Nearest to during: throughout, before, in, until, after, since, through, within,
# Nearest to it: she, he, this, there, usurpers, something, they, decision,
# Nearest to of: while, in, before, for, during, throughout, since, remotely,
# Nearest to these: different, numerous, various, certain, which, some, their, those,
# Nearest to not: never, now, still, also, intrinsically, graphs, ocogs, astros,
# Nearest to history: list, son, disapproval, origins, employment, theme, journal, course,
# Average loss at step 62000: 3.019837
# Average loss at step 64000: 3.020927
# Average loss at step 66000: 2.999023
# Average loss at step 68000: 3.008983
# Average loss at step 70000: 3.057304
# Nearest to been: become, gone, come, grown, occurred, remained, appeared, begun,
# Nearest to also: below, still, often, now, which, actually, disambiguation, sometimes,
# Nearest to they: you, we, he, there, she, pics, cry, xxv,
# Nearest to known: referred, described, seen, used, defined, such, regarded, follows,
# Nearest to was: is, were, became, becomes, remains, being, are, had,
# Nearest to five: six, seven, eight, four, three, zero, two, nine,
# Nearest to over: across, through, under, throughout, within, around, exmouth, radians,
# Nearest to no: little, any, nothing, only, kuiper, deconstruction, another, a,
# Nearest to called: used, known, considered, referred, termed, created, named, done,
# Nearest to UNK: longford, anu, dxm, marie, pistols, adolescents, pacheco, suburban,
# Nearest to during: throughout, before, since, in, after, at, until, through,
# Nearest to it: he, she, this, itself, something, there, narrators, detour,
# Nearest to of: including, prohibits, represents, like, delusional, following, from, remotely,
# Nearest to these: various, several, numerous, which, dicaprio, different, specific, whose,
# Nearest to not: now, still, never, actually, currently, graphs, concur, almost,
# Nearest to history: excesses, journal, reign, version, life, disapproval, origins, egalitarianism,
# Average loss at step 72000: 3.015817
# Average loss at step 74000: 3.021158
# Average loss at step 76000: 2.925986
# Average loss at step 78000: 2.929495
# Average loss at step 80000: 2.987331
# Nearest to been: become, remained, come, gone, grown, be, begun, occurred,
# Nearest to also: below, still, currently, actually, now, often, what, which,
# Nearest to they: you, we, he, there, she, humans, lectured, i,
# Nearest to known: referred, described, seen, regarded, defined, follows, used, such,
# Nearest to was: is, were, became, remains, are, becomes, being, makes,
# Nearest to five: four, seven, six, eight, three, zero, two, nine,
# Nearest to over: across, around, under, through, medicare, chronicling, throughout, before,
# Nearest to no: any, nothing, little, a, another, mycology, muonium, emacs,
# Nearest to called: named, used, included, masai, introduced, supported, created, termed,
# Nearest to UNK: cohen, seduce, novello, malpighi, ferdinand, fdl, aquino, landmines,
# Nearest to during: throughout, in, before, since, through, after, when, despite,
# Nearest to it: he, she, this, what, there, itself, detour, helices,
# Nearest to of: following, whereas, goodfellas, behind, include, including, pathologic, prohibits,
# Nearest to these: several, various, all, multiple, numerous, dicaprio, certain, many,
# Nearest to not: never, still, now, currently, jadwiga, augusta, actually, almost,
# Nearest to history: journal, implications, excesses, use, list, laserdisc, transcriptase, dominate,
# Average loss at step 82000: 2.970563
# Average loss at step 84000: 2.818814
# Average loss at step 86000: 2.926338
# Average loss at step 88000: 2.941409
# Average loss at step 90000: 2.930761
# Nearest to been: become, remained, come, occurred, grown, begun, appeared, gone,
# Nearest to also: still, below, currently, now, disambiguation, often, sometimes, always,
# Nearest to they: we, you, he, there, she, i, throwers, lectured,
# Nearest to known: referred, described, defined, regarded, seen, used, opposed, follows,
# Nearest to was: is, were, became, becomes, are, being, remains, has,
# Nearest to five: three, six, four, eight, seven, zero, two, nine,
# Nearest to over: across, around, under, owning, between, through, during, tram,
# Nearest to no: nothing, any, little, nye, another, presumes, a, mycology,
# Nearest to called: named, used, considered, referred, attributed, created, proposed, supported,
# Nearest to UNK: foods, boisbaudran, priscus, nonfiction, reinventing, poison, en, anu,
# Nearest to during: throughout, in, after, before, since, until, through, at,
# Nearest to it: she, he, this, ebionites, usurpers, what, detour, there,
# Nearest to of: including, include, goodfellas, in, for, featuring, ccf, gokturks,
# Nearest to these: several, various, multiple, numerous, different, their, certain, many,
# Nearest to not: never, now, nothing, still, graphs, actually, rarely, valeria,
# Nearest to history: concept, origins, list, journal, implications, map, origin, tradition,
# Average loss at step 92000: 2.827238
# Average loss at step 94000: 2.839361
# Average loss at step 96000: 2.873108
# Average loss at step 98000: 2.918909
# Average loss at step 100000: 2.832344
# Nearest to been: become, remained, grown, gone, come, occurred, appeared, existed,
# Nearest to also: below, now, currently, disambiguation, still, never, which, sometimes,
# Nearest to they: we, you, he, there, humans, she, pics, others,
# Nearest to known: referred, described, defined, regarded, seen, follows, opposed, used,
# Nearest to was: is, were, became, becomes, has, are, huldrych, had,
# Nearest to five: six, three, four, eight, seven, zero, nine, two,
# Nearest to over: under, around, during, off, across, about, pra, ludi,
# Nearest to no: nothing, any, another, a, mana, mycology, muonium, neither,
# Nearest to called: named, known, considered, used, referred, described, performing, attributed,
# Nearest to UNK: de, lactose, oslo, postgresql, croatia, el, universidade, deutsches,
# Nearest to during: throughout, after, in, before, at, until, through, since,
# Nearest to it: he, she, this, detour, voip, there, usurpers, ferocity,
# Nearest to of: including, prohibits, gj, woodson, tetra, heaps, after, despite,
# Nearest to these: various, several, numerous, which, those, whose, some, they,
# Nearest to not: never, still, almost, now, actually, augusta, graphs, nothing,
# Nearest to history: list, origins, journal, study, origin, map, concept, range,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
